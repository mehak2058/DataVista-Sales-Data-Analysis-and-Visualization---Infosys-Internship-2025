# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x=[1,2,3,4,5,6,7]
y=[20,40,30,40,30,50,30]
df = pd.DataFrame({"Days":x, "No of People":y})
df.head(7)
# Out:
#    Days  No of People
# 0     1            20
# 1     2            40
# 2     3            30
# 3     4            40
# 4     5            30
# 5     6            50
# 6     7            30

# %%
sns.lineplot(x="Days",y="No of People", data=df)
plt.show()

# %%
df2 = sns.load_dataset("tips")
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x="day",y="total_bill",data = df2,hue="sex",style="time")
plt.show()

# %%
df1 = sns.load_dataset("titanic")
sns.barplot(x='who', y='fare',data = df1)
plt.show()

# %%
sns.barplot(x='sex', y='fare',data = df1, hue="who", saturation=0.2)
plt.show()

# %%
from numpy import mean
sns.barplot(x='fare', y='who',data = df1, ci=False)
plt.show()
# Out:
# <ipython-input-20-a4522c18ea52>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='fare', y='who',data = df1, ci=False)

# %%
sns.barplot(x='fare',y='who',data=df1, facecolor=[1,1,1,0],edgecolor="0.2")
# Out:
# <Axes: xlabel='fare', ylabel='who'>

# %%
sns.histplot(x="total_bill", data = df2, kde = True)
plt.show()

# %%
sns.histplot(x="total_bill", data = df2, discrete = "false",edgecolor="red")
plt.show()

# %%
sns.histplot(x="total_bill", data = df2,hue="sex", palette="spring")
plt.show()

# %%
df3 = sns.load_dataset("exercise")
df3.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sns.scatterplot(x='time', y='pulse', data = df3)
plt.show()

# %%
sns.scatterplot(x='time',y='pulse',data=df3, hue='kind',palette="GnBu")
# Out:
# <Axes: xlabel='time', ylabel='pulse'>

# %%
sns.scatterplot(x='time', y='pulse', data = df3, size="diet")
# Out:
# <Axes: xlabel='time', ylabel='pulse'>

# %%
sns.scatterplot(x='time', y='pulse', data = df3, marker ="s", alpha=0.5)
plt.show()

# %%
data = np.random.randint(low=1, high=100, size=(10,10))
print(data)
# Out:
# [[22 43 76 56 33 66 51 74 69 36]
#  [99 34 43 11 94 17 57 39 85 33]
#  [32 31 58 63 91 33 68 76 90 69]
#  [82 80 88 41  8 25 39 63 59 79]
#  [96 48 35 68 10 51 33 44 39 32]
#  [21 50 67 28 90 85 36  5 23 28]
#  [33 99 89 55 93 83 91 10 19 82]
#  [68  3 23 97 15 30 68 76 39 67]
#  [ 8  7  1 12 33  4 83 94 71  4]
#  [83 97 41 90 58 39 26 58 55 95]]

# %%
sns.heatmap(data=data)
plt.show()

# %%
sns.heatmap(data=data, cmap="GnBu", alpha=0.5, linecolor="Green", linewidth="2", annot=True)
plt.show()

# %%
sns.countplot(x="tip", data = df2)
plt.show()

# %%
sns.countplot(y="sex",data=df2)
plt.show()

# %%
sns.countplot(x="sex",data=df2,hue="smoker",palette="PuBuGn", saturation=0.2)
plt.show()

# %%
sns.countplot(x="sex", data=df2, facecolor=[0,0,0,0], linewidth=8, edgecolor=sns.color_palette("GnBu",2))
plt.show()

# %%
sns.violinplot(x=df2["total_bill"])
plt.show()

# %%
sns.violinplot(x="sex", y="tip", data=df2, color="pink")
plt.show()

# %%
sns.violinplot(x="sex", y="tip", data=df2, hue="day")
plt.show()

# %%
sns.violinplot(x="day", y="tip", data=df2, hue="sex", split=True)
plt.show()

# %%
sns.boxplot(x=df2["tip"], data=df2)
plt.show()

# %%
sns.set(style="whitegrid")
sns.boxplot(x="sex", y="tip", data=df2, hue="smoker", palette="GnBu")
plt.show()

# %%
df4 = sns.load_dataset("iris")
sns.pairplot(data=df4, height=1.5)
plt.show()

# %%
sns.pairplot(data=df4, height=1.5, hue="species", palette="viridis")
plt.show()

# %%
sns.catplot(x="sex", y="tip", data=df2)
plt.show()

# %%
sns.catplot(x="sex", y="tip", data=df2, kind ="bar")
plt.show()

# %%
sns.catplot(x="sex", y="tip", data=df2, hue="smoker", col="time", height=3)
plt.show()

# %%
sns.stripplot(x=df2["tip"])
plt.show()

# %%
sns.stripplot(x="day", y="tip", data=df2, jitter=0.3)
plt.show()

# %%
sns.stripplot(x="day", y="tip", data=df2, hue="sex", dodge=True, palette="GnBu")
plt.show()

# %%
mp = sns.FacetGrid(df3, col="kind")
mp.map(sns.scatterplot, "time","pulse")
mp.add_legend()

# %%
mp = sns.FacetGrid(df3, col="kind", hue="time")
mp.map(sns.barplot, "time","pulse", order=["30 min","1 min","15 min"])

# %%
x = np.random.randn(100)
y = np.random.randn(100)

sns.kdeplot(x)
plt.show()

# %%
sns.kdeplot(y, fill=True, color="violet")
# Out:
# <Axes: ylabel='Density'>

# %%
setosa =df4.loc[df4.species == "setosa"]
virginica = df4.loc[df4.species == 'virginica']

sns.kdeplot(x=setosa.sepal_width, y=setosa.petal_width, data=df4)
plt.show()

# %%
sns.swarmplot(x="day", y="tip", data=df2, hue="time")
plt.show()

# %%
sns.set_style("darkgrid")
sns.countplot(x='day', data=df2)
plt.show()

# %%
sns.palplot(sns.color_palette("muted",10))
