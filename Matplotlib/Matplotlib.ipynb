# %% [markdown]
# # **Bar Plot**

# %%
import matplotlib.pyplot as plt

x=["python","c","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]

plt.xlabel("language", fontsize=15)
plt.ylabel("No.", fontsize=15)
plt.title("Graph", fontsize=15)

plt.bar(x,y,width=0.4,color="y",label="popularity")
plt.bar(x,z,width=0.4,color="r",label="popularity1")

plt.legend()
plt.show()

# %%
import numpy as np

x=["python","c","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]

width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel("language", fontsize=15)
plt.ylabel("No.", fontsize=15)
plt.title("Graph", fontsize=15)

plt.bar(p,y,width,color="y",label="popularity")
plt.bar(p1,z,width,color="r",label="popularity1")

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()

# %%
x=["python","c","c++","java"]
y=[85,70,60,82]
z=[20,30,40,50]

plt.xlabel("language", fontsize=15)
plt.ylabel("No.", fontsize=15)
plt.title("Graph", fontsize=15)

plt.barh(x,y,color="y",label="popularity")
plt.barh(x,z,color="r",label="popularity1")

plt.legend()
plt.show()

# %% [markdown]
# # **Line Chart**

# %%
y=np.array([20,50,40,30,50,40,30,70])

plt.plot(y,color="r")
plt.show()

# %%
y=np.array([20,50,40,30,50,40,30,70])
y1=np.array([40,20,10,40,30,60,80,40])

plt.plot(y,color="r",linewidth=3,marker="D")
plt.plot(y1, color="b",linestyle="--",marker="o")
plt.legend(["women","men"])
plt.show()

# %% [markdown]
# # **Scatter plot**

# %%
day=[1,2,3,4,5,6,7]
no=[2,3,1,2,5,3,6]
plt.scatter(day,no,color="r")
plt.title("Scatter Plot", fontsize=15)
plt.xlabel("Day", fontsize=15)
plt.ylabel("No.", fontsize=15)
plt.show()

# %%
day=[1,2,3,4,5,6,7]
no=[2,3,1,2,5,3,6]
no2=[2,4,6,7,3,1,5]
colors=[10,49,30,29,56,20,30]
sizes=[400,200,400,300,200,100,600]
plt.scatter(day,no,c=colors,s=sizes,cmap="viridis",alpha=0.5)
plt.scatter(day,no2,color="r",s=sizes,alpha=0.5)

t=plt.colorbar()
t.set_label("ColorBar", fontsize=15)
plt.title("Scatter Plot", fontsize=15)
plt.xlabel("Day", fontsize=15)
plt.ylabel("No.", fontsize=15)
plt.show()

# %% [markdown]
# # **Histogram plot**

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [54 57 39 28 15 41 10 46 28 57 18 30 21 10 27 12 14 50 59 26 38 27 45 26
#  37 33 25 13 22 55 23 33 56 50 11 22 53 29 51 25 55 45 56 15 54 12 53 53
#  52 30]

# %%
no=[17, 41, 54, 52, 54, 10, 46, 39, 16, 33, 32, 43, 22, 59, 14, 29, 12, 26, 15, 28, 42, 55, 51, 10,
 24, 23, 27, 19, 47, 16, 31, 38, 43, 24, 41, 59, 20, 39, 35, 10, 57, 49, 40, 24, 38, 38, 23, 43,
 55, 19]
l=[10,20,30,40,50,60]
plt.hist(no, color="g", edgecolor="r")

plt.title("histogram")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no1=[17, 41, 54, 52, 54, 10, 46, 39, 16, 33, 32, 43, 22, 59, 14, 29, 12, 26, 15, 28, 42, 55, 51, 10,
 24, 23, 27, 19, 47, 16, 31, 38, 43, 24, 41, 59, 20, 39, 35, 10, 57, 49, 40, 24, 38, 38, 23, 43,
 55, 19]
l=[10,20,30,40,50,60]
plt.hist(no1,"auto",(0,100), edgecolor="r")

plt.title("histogram")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()
# Out:
# <ipython-input-26-678f08478791>:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no1,"auto",(0,100), edgecolor="r")

# %%
no3=[17, 41, 54, 52, 54, 10, 46, 39, 16, 33, 32, 43, 22, 59, 14, 29, 12, 26, 15, 28, 42, 55, 51, 10,
 24, 23, 27, 19, 47, 16, 31, 38, 43, 24, 41, 59, 20, 39, 35, 10, 57, 49, 40, 24, 38, 38, 23, 43,
 55, 19]
l=[10,20,30,40,50,60]
plt.hist(no3,"auto",(0,100), edgecolor="r", cumulative=-1,bottom=10)

plt.title("histogram")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()
# Out:
# <ipython-input-25-e707416da6ef>:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(no3,"auto",(0,100), edgecolor="r", cumulative=-1,bottom=10)

# %%
no2=[17, 41, 54, 52, 54, 10, 46, 39, 16, 33, 32, 43, 22, 59, 14, 29, 12, 26, 15, 28, 42, 55, 51, 10,
 24, 23, 27, 19, 47, 16, 31, 38, 43, 24, 41, 59, 20, 39, 35, 10, 57, 49, 40, 24, 38, 38, 23, 43,
 55, 19]
l=[10,20,30,40,50,60]
plt.hist(no2, color="g", edgecolor="r", histtype="step")

plt.title("histogram")
plt.xlabel("python")
plt.ylabel("No.")
plt.show()

# %%
no2=[17, 41, 54, 52, 54, 10, 46, 39, 16, 33, 32, 43, 22, 59, 14, 29, 12, 26, 15, 28, 42, 55, 51, 10,
 24, 23, 27, 19, 47, 16, 31, 38, 43, 24, 41, 59, 20, 39, 35, 10, 57, 49, 40, 24, 38, 38, 23, 43,
 55, 19]
l=[10,20,30,40,50,60]
plt.hist(no2, color="g", edgecolor="r", log=True)

plt.title("histogram")
plt.xlabel("python")
plt.ylabel("No.")
plt.axvline(45,color="b")
plt.show()

# %% [markdown]
# # **Pie Chart**

# %%
xp=[10,20,30,40]
yp=["c","c++","Java","python"]
plt.pie(xp, labels=yp)
plt.show()

# %%
xpi=[10,20,30,40]
ypi=["c","c++","Java","python"]
ex=[0.3,0.0,0.0,0.0]
c=["r","b","g","y"]
plt.pie(xpi, labels=ypi, explode=ex,colors=c, autopct="%0.1f%%", shadow=True, radius=1.2, labeldistance=1.2, textprops={"fontsize":15})
plt.title("Pie Chart",fontsize=20)
plt.legend(loc=2)
plt.show()

# %%
plt.pie([1])
plt.show()

# %%
xpi=[10,20,30,40]
x1=[40,30,20,10]
ypi=["c","c++","Java","python"]

c=["r","b","g","y"]

plt.pie(xpi, labels=ypi,radius=1.5)
plt.pie([1],colors="w")

plt.show()

# %%
xpi=[10,20,30,40]
x1=[40,30,20,10]
ypi=["c","c++","Java","python"]

c=["r","b","g","y"]

plt.pie(xpi, labels=ypi,radius=1.5)
cr=plt.Circle(xy=(0,0),radius=1,facecolor="w")
plt.gca().add_artist(cr)

plt.show()

# %% [markdown]
# # **Violin Plot**

# %%
x = np.array([10,40,30,50,60,50,30,40,70,50,60,80,30,20,50,80])

plt.violinplot(x)
plt.show()

# %%
np.random.seed(10)
y1 = np.random.normal(100,10,200)
y2 = np.random.normal(95,10,200)
y3 = np.random.normal(80,10,200)
y4 = np.random.normal(80,10,200)

y = [y1,y2,y3,y4]

plt.violinplot(y, showmeans=True)
plt.show()

# %% [markdown]
# # **Stem Plot**

# %%
xs = [1,2,3,4,5,6]
ys = [2,2,5,1,4,3]

plt.stem(xs,ys)
plt.show()

# %%
xs = [1,2,3,4,5,6]
ys = [2,2,5,1,4,3]

plt.stem(xs,ys,linefmt=":",markerfmt="r+",bottom=0,basefmt="g",label="python",orientation="horizontal")
plt.legend()
plt.show()

# %%
x=np.linspace(0.1, 2**np.pi, 41)
y=np.exp(np.sin(x))

plt.stem(x,y)
plt.show()

# %%
x=np.linspace(0.1, 2**np.pi, 41)
y=np.exp(np.sin(x))

plt.stem(x,y,bottom=1)
plt.show()

# %% [markdown]
# # **Box Plot & Whisker**

# %%
x=[10,20,30,40,50,60,70]
plt.boxplot(x,labels=["python"],patch_artist=True,showmeans=True)
plt.show()
# Out:
# <ipython-input-7-b5e5b250e591>:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x,labels=["python"],patch_artist=True,showmeans=True)

# %%
x=[10,20,30,40,50,60,70,120]

plt.boxplot(x,labels=["python"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="g"))
plt.show()
# Out:
# <ipython-input-15-b32250b7eb3c>:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x,labels=["python"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="g"))

# %%
x=[10,20,30,40,50,60,70,120]

plt.boxplot(x,labels=["python"],showmeans=True,whis=2)
plt.show()
# Out:
# <ipython-input-14-526942d064af>:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(x,labels=["python"],showmeans=True,whis=2)

# %%
x=[10,20,30,40,50,60,70]
x1=[10,20,40,50,30,60,90]

y=[x,x1]
plt.boxplot(y,labels=["python","c++"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="g"))

plt.show()
# Out:
# <ipython-input-16-e01142309b95>:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(y,labels=["python","c++"],showmeans=True,sym="g+",boxprops=dict(color="r"),capprops=dict(color="g"))

# %% [markdown]
# # **Area & Stack Plot**

# %%
x = [1,2,3,4,5]
area1 = [2,3,2,5,4]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l=["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="zero")

plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
area1 = [2,3,2,5,4]
area2 = [2,3,4,5,6]
area3 = [1,3,2,4,2]

l=["area1","area2","area3"]

plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","y"],baseline="wiggle")

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %% [markdown]
# # **Step Plot**

# %%
x=[1,2,3,4,5]
y=[1,2,3,5,4]

plt.step(x,y)

plt.show()

# %%
x=[1,2,3,4,5]
y=[1,2,3,5,4]

plt.step(x,y,color="r",marker="o",ms=10,mfc="g",label="python")

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(loc=2)
plt.grid()
plt.show()

# %% [markdown]
# # **Fill_Between**

# %%
x=np.array([1,2,3,4,5])
y=np.array([1,2,3,4,5])

plt.plot(x,y,color="r")

plt.fill_between(x,y,color="g",where=(x>=2) & (x<=4),alpha=0.5)

plt.title("Python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.show()

# %%
a = np.linspace(0,2*3.14,50)
b=np.sin(a)

plt.plot(a,b)
plt.fill_between(a, b, 0, where = (a > 1.5) & (a<=3.2))
plt.show()

# %% [markdown]
# # **Subplot**

# %%
x=[1,2,3,4]
y=[1,2,3,4]
plt.subplot(2,2,1)
plt.plot(x,y,color="r")

plt.subplot(2,2,2)
plt.pie([1],colors="r")

x1=[10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x)

x2=["a","s","d","f"]
y2=[10,20,30,40]
plt.subplot(2,2,4)
plt.bar(x2,y2)

plt.show()

# %% [markdown]
# # **3D Surface Plot**

# %%
fig = plt.figure()
ax = plt.axes(projection = "3d")
